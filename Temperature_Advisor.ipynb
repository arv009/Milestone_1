# %% [markdown]
# # Temperature Checker V2

# %%
def temperature_today(temperature): # Gets the temperature today
  
  if temperature >= 35 and temperature <= 50:
    return f"It's a hot day today! The temperature is {temperature} degrees Celsius. Wear light clothing and stay hydrated."
  elif temperature >= 25:
    return f"It's a warm day today! The temperature is {temperature} degrees Celsius. Wear light clothing."
  elif temperature >= 15:
    return f"It's a cool day today! The temperature is {temperature} degrees Celsius. Wear a jacket or sweater."
  else:
    return f"It's a cold day today! The temperature is {temperature} degrees Celsius. Wear warm clothing and stay indoors if possible."

while True: # The while loop will keep running until it hits 'break'
    temperature_input = float(input("Please enter today's temperature in Celsius: ")) # Get the temperature input and convert it into Float

    try:
        print (temperature_today(temperature_input))
        break
    except ValueError:
        print("Please enter a valid number for the temperature.") # Handles the error when the input is not a valid number
# Out:
# It's a hot day today! The temperature is 45.0 degrees Celsius. Wear light clothing and stay hydrated.

# %%
assert temperature_today(36) == "It's a hot day today! The temperature is 36 degrees Celsius. Wear light clothing and stay hydrated."
assert temperature_today(28) == "It's a warm day today! The temperature is 28 degrees Celsius. Wear light clothing."
assert temperature_today(20) == "It's a cool day today! The temperature is 20 degrees Celsius. Wear a jacket or sweater."
assert temperature_today(12) == "It's a cold day today! The temperature is 12 degrees Celsius. Wear warm clothing and stay indoors if possible."
print("All checks passed!")
# Out:
# All checks passed!
